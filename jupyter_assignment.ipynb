# %% [markdown]
# <a href="https://colab.research.google.com/github/KoWalevDV/Data-Base-2023-2024/blob/main/jupyter_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Основы машинного обучения: лабораторная работа №1
# ## Задание 1. Знакомство с Jupyter и Google Colab
#
# Все файлы этой лабораторной работы содержатся в репозитории на GitHub. Лабораторная работа состоит из нескольких заданий. При выполнении каждого задания необходимо следовать инструкциям и заполнить недостающие части кода и/или текста в соответствующем ноутбуке Jupyter.
#
# Когда вы принимаете задание к выполнению (например, перейдя по ссылке на GitHub Classroom, выданной преподавателем), автоматически создается ваш личный репозиторий (fork в терминах GitHub), содержащий копию файлов из шаблонного репозитория с заданием. Вам должно прийти сообщение со ссылкой на только что созданный новый репозиторий; обычно это будет что-то вроде `https://github.com/<course_name>/<assignment_name>-<username>`, где "`<course_name>`" - сокращенное название курса, "`<assignment_name>`" - сокращенное название задания, а "`<username>`" - имя пользователя на GitHub.
#
# **Если вы уже приняли это задание и просматриваете этот файл в Google Colaboratory, пожалуйста, продолжайте. Если вы еще не приняли задание или не просматриваете этот ноутбук в Google Colaboratory, пожалуйста, следуйте инструкциям преподавателя, чтобы выполнить это задание.**
#
# ### Цели задания
#
# 1.   Научиться использовать ноутбуки в среде Jupyter (Colaboratory)
# 2.   Настроить аккаунт для работы в Google Colaboratory
#
# ### Оценивание и баллы¶
#
# За это задание в общей сложности можно получить до 2 баллов. Максимальный балл можно получить, если все автоматические тесты пройдут успешно.

# %% [markdown]
# ## Часть 1. GitHub и ноутбуки Jupyter, Google Colaboratory
#
# Начать необходимо с просмотра [этого ноутбука](introduction_and_overview.ipynb), чтобы ознакомиться с ноутбуками Jupyter и средой Google Colaboratory (сокращенно - Colab). Открыть ознакомительный ноутбук в Colab можно перейдя по ссылке `https://colab.research.google.com/github/<ORGANIZATION>/<REPOSITORY>/blob/main/introduction_and_overview.ipynb`, где `<ORGANIZATION>` необходимо заменить на название организации на GitHub, используемой в этом курсе (это упомянутое выше "сокращенное название курса"), а `<REPOSITORY>` - заменить на название личного репозитория студента (`<assignment_name>-<username>` выше). Следуйте инструкциям в ознакомительном ноутбуке, чтобы настроить свою учетную запись Google Colaboratory.
#
# Измените код в следующей ячейке, чтобы указать, что вы изучили ознакомительный ноутбук, прочитали о работе ноутбуков Jupyter/Colaboratory, настроили свою учетную запись Google Colaboratory и настроили свою учетную запись на GitHub. Вам нужно изменить каждую переменную с `False` на `True`, чтобы показать, какие задачи вы выполнили (по самоотчету). Также обновите переменную `github_username`, чтобы указать свое имя пользователя на GitHub.

# %%
### BEGIN YOUR CODE
#I have read through the Introduction and Overview notebook
READ_INTRODUCTION = True

#I understand (at a high level) what Jupyter notebooks are and how to read and
#interact with them (or I have been in touch with the course instructor to ask for help)
LEARNED_ABOUT_JUPYTER = True

#I've created (or already have) a Google account and can access Google
#Colaboratory under my own account
ACCESS_COLABORATORY = True

#I've created a GitHub account
CREATED_GITHUB_ACCOUNT = True
github_username = 'KoWalevDV'

#My info
my_name = 'Daniil'
### END YOUR CODE

# %% [markdown]
# ## Часть 2. Базовый вывод информации
#
# Функция `print` может использоваться как для отображения результатов вычислений, так и для отладки кода. Один из базовых подходов к отладке кода в Jupyter-ноутбуке — периодически выводить диагностические сообщения с помощью `print`, чтобы понять, что происходит в конкретном месте кода.
#
# Самый простой способ использования функции `print` — вызвать `print(...)`, заменив "`...`" на текст, который необходимо вывести. Текст должен быть заключен в одинарные (`'`) или двойные (`"`) кавычки, вот так:
#
# ```
# print('Hello, world!')
# ```
#
# Измените код в следующей ячейке, чтобы вывести приветствие себе (например, `"Hello, Noname!"` или что-то в этом роде, заменив `"Noname"` на ваше собственное имя, заданное в предыдущей ячейке). Проверьте результат, нажав shift + enter, чтобы выполнить код в ячейке. Приветствие появится под ячейкой с кодом.

# %%
### BEGIN YOUR CODE
print('Hello, Daniil!')
### END YOUR CODE
# Out:
# Hello, Daniil!

# %% [markdown]
# ### Объявление функций
#
# Внесите небольшое изменение в программу "Привет, мир!" выше. Вместо того чтобы выводить приветствие, напишите функцию, которая принимает ваше имя `name` в качестве входного параметра и возвращает строку `'Hello, <name>!'`, заменяя `<name>` на то, что указал вызвавший функцию пользователь.

# %%
def greet(name):
  ### BEGIN YOUR CODE
  return f'Hello,{name}!'
  ### END YOUR CODE

# %% [markdown]
# #### Повышение отказоустойчивости кода
#
# Что произойдет, если на вход функции поступит список людей? Можно ли сделать так, чтобы код приветствовал нескольких людей, если на вход функции поступит список имен (например, `'Hello, Alex and Bertha!'` или `'Hello, Arvin, Beth, and Calvin!'`)? А что, если кто-то передаст другой тип данных вместо `str` (`'Hello, 3.14!'`)? Может ли ваш код корректно обработать эти ситуации?
#
# Чтобы понять, какие ситуации будут проверяться, ознакомьтесь с таблицей ниже:
#
# |function|args                  |solution           |points|
# |--------|----------------------|-------------------|------|
# |identity|READ_INTRODUCTION     |1                  |0.1   |
# |identity|LEARNED_ABOUT_JUPYTER |1                  |0.1   |
# |identity|ACCESS_COLABORATORY   |1                  |0.1   |
# |identity|CREATED_GITHUB_ACCOUNT|1                  |0.1   |
# |greet   |\["Test User"\]       |"Hello, Test User!"|0.599 |
#
#   - Столбец `function` указывает, какая функция из этого ноутбука будет выполнена. (Примечание: функция `identity` всегда возвращает значение своего входного аргумента.)
#   - Столбец `args` указывает на один или более (безымянных) аргументов, которые будут переданы указанной в столбце `function` функции.
#   - Столбец `solution` указывает, какой ответ ожидается в качестве правильного.
#   - Столбец `points` указывает, сколько баллов будет начислено при успешном прохождении соответствующего теста. В дополнение к перечисленным в таблице публично видимым тестам, код также будет проверяться с помощью скрытых тестов. Итоговая оценка за задание состоит из суммы баллов за публичным и скрытиые тесты.

# %% [markdown]
# ### Получение помощи и справочная информация по языку программирования Python
#
# Чтобы узнать больше о любой команде или функции Python, вы можете ввести `?<имя функции>` в ячейку кода, заменив `"<имя функции>"` на фактическое имя функции (например, `print`), и нажать shift + enter, чтобы выполнить ячейку с кодом. Примеры:
# ```python
# >> ?print
# >> help(print)
# ```

# %% [markdown]
# ## Часть 3. Сдача задания на проверку
#
# После того как все части задания выполнены, задание необходимо сдать на проверку.
#
# Дальнейшие инструкции предполагают работу в среде Google Colaboratory.
#
# Сначала убедитесь, что вы сохранили свой ноутбук (`Файл` > `Сохранить`).
#
# Затем нажмите на пункт меню `Файл` (в верхнем левом углу) и выберите `Сохранить копию на GitHub...`. Появится диалоговое окно с вопросом, где сохранить файл. Вы должны сохранить свою копию этого ноутбука в репозитории GitHub c вашим персональным заданием (то есть, что-то вроде `https://github.com/<course_name>/<assignment_name>-<username>`, где "`<course_name>`", "`<assignment_name>`" и "`<username>`" обсуждались выше). Сохранение копии этого ноутбука в вашем персональном репозитории GitHub, расположенном в организации, привязанной к данному курсу, считается "сдачей" задания. Обратите внимание, что имя файла в репозитории не должно меняться. Если Colab по умолчанию добавит к имени файла приставку "Copy of ", то её необходимо удалить и сохранить файл с ноутбуком под его первоначальным именем, перезаписав уже имеющийся файл. За счет использования системы контроля версий предыдущая версия ноутбука не пропадет и при необходимости к ней всегда можно будет вернуться.
#
# ### Решение проблем
#
# Если вы не можете найти свой персональный репозиторий на GitHub в выпадающем меню "Репозитории" в диалоговом окне сохранения копии на GitHub, наиболее вероятная причина в том, что вы не предоставили Colaboratory доступ к своим приватным репозиториям. Следуйте инструкциям по настройке и сдаче работы в README.md, чтобы перепроверить, что доступ к приватным репозиториям GitHub был предоставлен для Google Colaboratory.
#
# Если проблемы сохраняются, следует задать вопрос в канале в Discord, посвященном данному курсу (ссылка в личном кабинете). В сообщении необходимо предоставить достаточно информации, чтобы преподаватель и другие участники чата смогли понять проблему. В частности, опишите подробно:
# - что вы пытались сделать;
# - какой результат вы ожидали;
# - что получилось вместо ожидаемого результата;
# - предоставьте любую другую информацию, которую считаете важной или релевантной.
#
#
# ### Проверка на адекватность
#
# После того как вы успешно сдадите свое задание, веб-браузер откроет новую вкладку (или окно), в которой будет репозиторий на GitHub, куда был сохранен ваш ноутбук с заданием. Проверьте ноутбук на этой странице в GitHub и убедитесь, что ваш ноутбук корректен, т.е. что он содержит все изменения, которые вы внесли в исходный файл с заданием.
#
# ## Повторная сдача
#
# До дедлайна задание можно пересдавать произвольное число раз. Для этого необходимо обновить копию вашего файла с заданием (и его решением) в вашем персональном репозитории. По истечении срока сдачи лабораторной работы, последняя актуальная версия ноутбука в вашем персональном репозитории на GitHub будет автоматически засчитана в качестве итогового решения задания. Кроме синхронизации вашей копии ноутбука, хранящейся в Colaboratory, с вашим репозиторием на GitHub, никаких дополнительных действий для сдачи этого задания не требуется. Ранее поданные версии вашего задания останутся в истории коммитов в репозитории и не будут учитываться при выставлении оценки.
#
# ### Повторное выполнение задания с нуля
#
# Чтобы повторно выполнить задание с нуля (с использованием оригинального шаблона Jupyter-ноутбука для этого задания), обратитесь к преподавателю для восстановления в вашем репозитории исходной версии шаблона Jupyter-ноутбука для этого задания. Вы также можете самостоятельно найти и использовать более раннюю версию ноутбука (до внесения изменений при выполнении задания) в истории коммитов на GitHub. Для этого можно найти коммит "Initial commit" в списке коммитов, открыть на GitHub состояние репозитория на момет этого коммита, перейти в нужный Jupyter-ноутбук и скопировать путь к нему в адресной строке. Путь будет иметь вид: `https://github.com/<course_name>/<assignment_name>-<username>/blob/<commit_sha>/jupyter_assignment.ipynb`, где `<commit_sha>` - идентификатор коммита, например, `main` или `e547d8a6542ba3d76e2489b8504ab052c46f180a`. Открыть эту версию ноутбука в Colab можно перейдя по ссылке `https://colab.research.google.com/github/<course_name>/<assignment_name>-<username>/blob/<commit_sha>/jupyter_assignment.ipynb#scrollTo=7ZlQqKauX_Hp`. Проще всего это сделать, скопировав из ссылки на GitHub все, что идет после `https://github.com/`, и вставив скопированную часть после `https://colab.research.google.com/github/`.
#
#
# ### Изменение предыдущей версии сданного задания
#
# Вместо повторного выполнения задания с нуля можно использовать предыдущую версию сданного задания как отправную точку для дальнейших правок. Самый простой способ сделать это — зайти в Google Colaboratory ([ссылка](https://colab.research.google.com/)) и выбрать ноутбук с вашим заданием в диалоговом окне. Он должен находиться на вкладке "Недавние". Или, если вы работали с другими файлами, вы можете перейти к нужному ноутбуку на вкладке `Google Drive` (все ноутбуки Colaboratory сохраняются в Google Drive при выборе пункта меню `Файл` > `Сохранить`) или на вкладке GitHub. После внесения изменений снова сохраните ноутбук на GitHub, чтобы повторно сдать задание.
#
#
# ### Обратная связь
#
# Каждый раз, когда вы отправляете обновленный Jupyter-ноутбук в ваш репозиторий GitHub, запускаются автоматические тесты, и ваша работа оценивается. Логи автоматических тестов с результатами оценивания можно найти на вкладке `Actions` репозитория.
